# %%
ticker='NFLX'
view='NMV'

# %%
from visiblealpha_data_api import VisibleAlphaData
vadata = VisibleAlphaData('ashim.mishra@visiblealpha.com', 'welcome@213', 'pandas')
output = vadata.parameter_list([ticker], view)
output
# Out:
#     Ticker     Statement                                          Parameter  \
# 0     NFLX  DomStreaming        Domestic Streaming - Free subs. - Beginning
# 1     NFLX  DomStreaming          Domestic Streaming - Free subs. - Net add
# 2     NFLX  DomStreaming           Domestic Streaming - Free subs. - Ending
# 3     NFLX  DomStreaming        Domestic Streaming - Paid subs. - Beginning
# 4     NFLX  DomStreaming          Domestic streaming - Paid subs. - Net add
# 5     NFLX  DomStreaming           Domestic Streaming - Paid subs. - Ending
# 6     NFLX  DomStreaming       Domestic Streaming - Total subs. - Beginning
# 7     NFLX  DomStreaming         Domestic Streaming - Total subs. - Net add
# 8     NFLX  DomStreaming          Domestic Streaming - Total subs. - Ending
# 9     NFLX  DomStreaming                Domestic Streaming - Avg paid subs.
# 10    NFLX  DomStreaming  Domestic Streaming - Avg. rev. per paid subs. ...
# ...
